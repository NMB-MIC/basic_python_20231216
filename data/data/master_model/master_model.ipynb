# %% [markdown]
# ## Upload excel file

# %%
import pandas as pd
from datetime import date
import os

# %%
path = os.getcwd()
file_extension = '.xls'

xlxs_file_list = []
for root,dirs,files in os.walk(path):
    for name in files: 
        if name.endswith(file_extension):
            file_path = os.path.join(root,name)
            xlxs_file_list.append(file_path)
print(xlxs_file_list)
# Out:
# ['d:\\My Documents\\Desktop\\press_backup\\master_model\\master_model.xls']

# %%
today = date.today()
today_date = str(today).split("-")[-1]
month = str(today).split("-")[-2]
year = str(today).split("-")[-3]

dfs = []
for f in xlxs_file_list:
    df = pd.read_excel(f)
    dfs.append(df)

# %%
dfs = pd.concat(dfs)
dfs
# Out:
#     model_name  width  thickness
# 0          R50    0.2         46
# 1          R52    0.2         52
# 2          R54    0.2         46
# 3          R55    0.3         61
# 4          R56    0.3         64
# ..         ...    ...        ...
# 103        S30    0.1         14
# 104        S31    0.1         16
# 105        S32    0.1         16
# 106        S33    0.1         14
# 107        S34    0.1         16
#
# [108 rows x 3 columns]

# %%
df1 = dfs.copy()
df1['registered_at'] = today
df1
# Out:
#     model_name  width  thickness registered_at
# 0          R50    0.2         46    2022-11-17
# 1          R52    0.2         52    2022-11-17
# 2          R54    0.2         46    2022-11-17
# 3          R55    0.3         61    2022-11-17
# 4          R56    0.3         64    2022-11-17
# ..         ...    ...        ...           ...
# 103        S30    0.1         14    2022-11-17
# 104        S31    0.1         16    2022-11-17
# 105        S32    0.1         16    2022-11-17
# 106        S33    0.1         14    2022-11-17
# 107        S34    0.1         16    2022-11-17
#
# [108 rows x 4 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:pgadmin@localhost:5432/machine_control')

with engine.connect() as connection:
  df1.to_sql('app_machine_control_mastermodel', connection, index=False,if_exists='append')

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:1234@192.168.1.16:5432/test')

with engine.connect() as connection:
  df1.to_sql('test_table', connection, index=False,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File c:\Users\lbj6639\Miniconda3\envs\python_training\lib\site-packages\sqlalchemy\engine\base.py:1880, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1879     if not evt_handled:
# -> 1880         self.dialect.do_executemany(
#    1881             cursor, statement, parameters, context
#    1882         )
#    1883 elif not parameters and context.no_parameters:
#
# File c:\Users\lbj6639\Miniconda3\envs\python_training\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:982, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     981     xtras = self._psycopg2_extras()
# --> 982     context._psycopg2_fetched_rows = xtras.execute_values(
#     983         cursor,
#     984         statement,
# ...
